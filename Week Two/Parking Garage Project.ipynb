# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
class ParkingGarage:

    """
    Attributes:
    - tickets - needs to be a list
    - parking_spaces - needs to be a list
    - current_ticket - needs to be a dictionary

    Methods:
    - take_ticket() - This should decrease the amount of tickets available by 1
                    - This should decrease the amount of parking spaces available by 1

    - pay_for_parking() - Display an input that waits for an amount from the user and store it in a variable
                        - If the payment variable is not empty then ->  display a message to the user that 
                          their ticket has been paid and they have 15mins to leave
                        - This should update the "currentTicket" dictionary key "paid" to True

    - leave_garage() - If the ticket has been paid, display a message of "Thank You, have a nice day"
                     - If the ticket has not been paid, display an input prompt for payment
                     - Once paid, display message "Thank you, have a nice day!"
                     - Update parkingSpaces list to increase by 1
                     - Update tickets list to increase by 1

    """
    tickets = ['red', 'blue', 'green']
    spaces = ['front', 'middle', 'back']
    ticket_price = 4
    
    
    def __init__(self, license_plate):
        """Creating an identity for the driver when they come to the parking lot and if there are any
    parking spots available."""
        if len(self.spaces) == 0:
            print("Lot is full, please go elsewhere.")
            self.can_enter = False
        else:
            self.plate_no = license_plate
            self.can_enter = True

    def __repr__(self):
        """Define where the car is after it has taken a ticket"""
        try:    
            return f"Car with plate {self.current_ticket['id']} has ticket {self.current_ticket['ticket']} and is parked at {self.current_ticket['space']} "
        except:
            return "That car may have visited our garage, but it is not parked here."
    
    def take_ticket(self):
        """Once the driver has created an identity in the parking garage, it registers it to the garage database"""
        if self.can_enter == False:
            print("Garage is full, please go elsewhere")
        else:
            self.current_ticket = {
            'id': self.plate_no,
            'space' : self.spaces.pop(),
            'ticket': self.tickets.pop(),
            'paid' : False}

    def pay_for_parking(self):
        """Define if the driver paid for the ticket and once they leave, append back the available parking space"""
        if self.can_enter == False:
            print("You are not parked here. Look elsewhere for your car.")
        else:
            while True:
                payment = input(f"Enter ${self.ticket_price} to pay for your parking: ")
                if payment:
                    print("Payment received, you have 15 minutes to exit")
                    print("Thank you, have a nice day!")
                    self.current_ticket['paid'] = True
                    self.spaces.append(self.current_ticket['space'])
                    self.tickets.append(self.current_ticket['ticket'])
                    del self.current_ticket
                    break

car1 = ParkingGarage('4444')
print(car1)
car1.take_ticket()
print(car1)
car1.pay_for_parking()


car2 = ParkingGarage('555')
car2.take_ticket()
car3 = ParkingGarage('45678')
car3.take_ticket()
car4 = ParkingGarage('5555')
car4.take_ticket()
car5 = ParkingGarage('123')
car5.take_ticket()

all_cars = [car1, car2, car3, car4, car5]

for car in all_cars:
    print(car)
# Out:
# That car may have visited our garage, but it is not parked here.
# Car with plate 4444 has ticket green and is parked at back
# Payment received, you have 15 minutes to exit
# Thank you, have a nice day!
# Lot is full, please go elsewhere.
# Garage is full, please go elsewhere
# That car may have visited our garage, but it is not parked here.
# Car with plate 555 has ticket green and is parked at back
# Car with plate 45678 has ticket blue and is parked at middle
# Car with plate 5555 has ticket red and is parked at front
# That car may have visited our garage, but it is not parked here.
